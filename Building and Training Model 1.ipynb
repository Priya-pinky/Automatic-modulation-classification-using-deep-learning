# %% [markdown]
# ## In this notebook, the proposed model classifies the image data into two classes (PSK and QAM).

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import os
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers.core import Dense
from keras.layers.core import Flatten
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
from keras.preprocessing import image
from matplotlib import pyplot as plt
from PIL import Image
import copy
from tensorflow.keras.models import model_from_json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### The paths for the training, validation and the testing data.

# %%
data_dir='/content/drive/MyDrive/Summer Intern Project/dataset/train'
test_data_dir='/content/drive/MyDrive/Summer Intern Project/dataset/test'
val_data_dir='/content/drive/MyDrive/Summer Intern Project/dataset/valid'

# %%
classes=[str(i) for i in range(6)]

# %%
train_images_per_class=1050
test_images_per_class=100
valid_images_per_class=100

# %% [markdown]
# ## Checking out some sample images for classification

# %%
# Opens a image in RGB mode
newsize=(224,224)

sample_imgs=[700,700,700,700,800,800]
imgs=[]
for i in range(6):
  imgs.append(Image.open("/content/drive/MyDrive/Summer Intern Project/dataset/train/"+str(i)+'/'+str(sample_imgs[i])+".png").resize(newsize))
# create figure
fig = plt.figure(figsize=(15, 15))
  
# setting values to rows and column variables
rows = 3
columns = 2


for i in range(6):
  # Adds a subplot at the ith position
  fig.add_subplot(rows, columns, i+1)
  plt.imshow(imgs[i])

# %% [markdown]
# ## This is the function that fills the given values in a circle shape with specifies center and diameter.
# ### This function is very handy in generating a circular mask.

# %%
def gen_circle(img: np.ndarray, center: tuple, diameter: int,fill_val: int) -> np.ndarray:
  
    """
        Creates a matrix of ones filling a circle.
    """

    # gets the radius of the image
    radius  = diameter//2

    # gets the row and column center of the image
    row, col = center 

    # generates theta vector to variate the angle
    theta = np.arange(0, 360)*(np.pi/180)

    # generates the indexes of the column
    y = (radius*np.sin(theta)).astype("int32") 

    # generates the indexes of the rows
    x = (radius*np.cos(theta)).astype("int32") 

    # with:
    # img[x, y] = 1
    # you can draw the border of the circle 
    # instead of the inner part and the border. 

    # centers the circle at the input center
    rows = x + (row)
    cols  = y + (col)

    # gets the number of rows and columns to make 
    # to cut by half the execution
    nrows = rows.shape[0] 
    ncols = cols.shape[0]

    # makes a copy of the image
    img_copy = np.copy(img)

    # We use the symmetry in our favour
    # does reflection on the horizontal axes 
    # and in the vertical axes

    for row_down, row_up, col1, col2 in zip(rows[:nrows//4],
                            np.flip(rows[nrows//4:nrows//2]),
                            cols[:ncols//4],
                            cols[nrows//2:3*ncols//4]):
    
        img_copy[row_up:row_down, col2:col1] = fill_val

    return img_copy

# %% [markdown]
# ## The function to preprocess the data before feeding it to the model.

# %%
def preprocess_data(X,Y,n):
  X_p=preprocess_input(X)
  Y_p=tf.keras.utils.to_categorical(Y,n)
  return (X_p,Y_p)

# %% [markdown]
# ## Reading the training data:

# %%
train_data=[]
img_height,img_width=224,224
for cls in classes:
  print(cls)
  for i in range(train_images_per_class):
    img_path=data_dir+'/'+cls+'/'+str(i)+'.png'
    img=image.load_img(img_path,target_size=(img_height,img_width))
    img_data=image.img_to_array(img)
    train_data.append(img_data)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Reading the Validation data:

# %%
valid_data=[]
img_height,img_width=224,224
for cls in classes:
  print(cls)
  for i in range(valid_images_per_class):
    img_path=val_data_dir+'/'+cls+'/'+str(i)+'.png'
    img=image.load_img(img_path,target_size=(img_height,img_width))
    img_data=image.img_to_array(img)
    valid_data.append(img_data)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Converting the image data into Numpy arrays.

# %%
train_data=np.asarray(train_data)

# %%
valid_data=np.asarray(valid_data)

# %% [markdown]
# # **Building First stage Model:**

# %% [markdown]
# #### The very first stage of the model classifies the images into 2 categories, the PSK and the QAM classes.

# %%
classes_1=['0','1']
#'0' - PSK
#'1' - QAM

# %%
train_data_1=copy.deepcopy(train_data)

# %%
valid_data_1=copy.deepcopy(valid_data)

# %%
train_label_1=[]
train_label_1[:2*train_images_per_class]=['0']*2*train_images_per_class
train_label_1[2*train_images_per_class:]=['1']*4*train_images_per_class
train_label_1=np.asarray(train_label_1)

# %%
valid_label_1=[]
valid_label_1[:2*valid_images_per_class]=['0']*2*valid_images_per_class
valid_label_1[2*valid_images_per_class:]=['1']*4*valid_images_per_class
valid_label_1=np.asarray(valid_label_1)

# %% [markdown]
# ## Defining each type of filter applied on corresponding layer of the images:

# %%
# R filter
#four concentric circles - centres
diam = 25
x_dis=40
y_dis=50
r_filter_dim=[(y_dis,x_dis),(224-y_dis,x_dis),(y_dis,224-x_dis),(224-y_dis,224-x_dis)]

fil=np.zeros((224,224),dtype=int)
for i in range(4):
  fil=gen_circle(fil,r_filter_dim[i],diam,1)
plt.imshow(fil)

# %%
# G filter

# ring-outer radius and inner radius
g_filter_dim=[85,65]
val=[1,0]
fil=np.zeros((224,224),dtype=int)
for i in range(2):
  fil=gen_circle(fil,(112,112),2*g_filter_dim[i],val[i])
plt.imshow(fil)

# %%
# B filter

# circle-diameter
b_filter_dim=90

fil=np.zeros((224,224),dtype=int)
fil=gen_circle(fil,(112,112),b_filter_dim,1)
plt.imshow(fil)

# %%
def apply_filter_1(im):
  '''

  '''
  center = (112,112)

  #red layer filter 
  fil=np.zeros((224,224),dtype=int)
  for i in range(4):
    fil=gen_circle(fil,r_filter_dim[i],diam,1)
  im[:,:,0]=im[:,:,0]*fil

  #blue layer filter
  fil=np.zeros((224,224),dtype=int)
  g_filter_dim=[85,65]
  val=[1,0]
  fil=np.zeros((224,224),dtype=int)
  for i in range(2):
    fil=gen_circle(fil,center,2*g_filter_dim[i],val[i])
  im[:,:,1]=im[:,:,1]*fil


  #blue layer filter
  fil=np.zeros((224,224),dtype=int)
  fil=gen_circle(fil,center,b_filter_dim,1)
  im[:,:,2]=im[:,:,2]*fil
  
  return im

# %%
def disp_filter_image_1(im):
  im=apply_filter_1(im)
  plt.imshow(im)
  plt.axis('off')

# %% [markdown]
# ### Sample Images looks like this after the filters are being applied:

# %%
fil_imgs=[]
for i in range(6):
  fil_imgs.append(Image.open("/content/drive/MyDrive/summer intern/dataset/train/"+str(i)+'/'+str(sample_imgs[i])+".png").resize(newsize))
# create figure
fig = plt.figure(figsize=(15, 15))
  
# setting values to rows and column variables
rows = 3
columns = 2

for i in range(6):
  # Adds a subplot at the ith position
  fil_imgs[i]=apply_filter_1(np.array(fil_imgs[i]))
  fig.add_subplot(rows, columns, i+1)
  plt.imshow(fil_imgs[i])

# %% [markdown]
# ## Applying the Filters on Training data

# %%
for i in range(len(train_label_1)):
  train_data_1[i]=apply_filter_1(train_data_1[i])

# %% [markdown]
# ## Applying the Filters on validation data

# %%
for i in range(len(valid_label_1)):
  valid_data_1[i]=apply_filter_1(valid_data_1[i])

# %%
print(valid_data_1.shape)
# Out:
# (600, 224, 224, 3)

# %%
train_data_1,train_label_1=preprocess_data(train_data_1,train_label_1,2)

# %%
valid_data_1,valid_label_1=preprocess_data(valid_data_1,valid_label_1,2)

# %%
print(train_data_1.shape,train_label_1.shape)
# Out:
# (3000, 224, 224, 3) (3000, 2)

# %%
print(valid_data_1.shape,valid_label_1.shape)
# Out:
# (600, 224, 224, 3) (600, 2)

# %% [markdown]
# ## Building and training the model-1

# %%
resnet_model_1 = Sequential()
input_t=tf.keras.Input(shape=(224,224,3))
pretrained_model_1= tf.keras.applications.ResNet50(include_top=False,
                   input_tensor=input_t,
                   pooling='max',classes=2,
                   weights='imagenet')
for layer in pretrained_model_1.layers:
        layer.trainable=False

resnet_model_1.add(pretrained_model_1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
resnet_model_1.add(Flatten())
resnet_model_1.add(Dense(512, activation='relu'))
resnet_model_1.add(Dense(2, activation='softmax'))

# %%
resnet_model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 24,637,826
# Trainable params: 1,050,114
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
resnet_model_1.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

history = resnet_model_1.fit(train_data_1,train_label_1, validation_data=(valid_data_1,valid_label_1),batch_size=32, epochs=20,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/20
# 94/94 [==============================] - 32s 173ms/step - loss: 4.1158 - accuracy: 0.7320 - val_loss: 0.6861 - val_accuracy: 0.7200
# Epoch 2/20
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6048 - accuracy: 0.8260 - val_loss: 0.5774 - val_accuracy: 0.7517
# Epoch 3/20
# 94/94 [==============================] - 16s 170ms/step - loss: 0.3526 - accuracy: 0.8677 - val_loss: 0.3290 - val_accuracy: 0.8367
# Epoch 4/20
# 94/94 [==============================] - 18s 196ms/step - loss: 0.3457 - accuracy: 0.8717 - val_loss: 0.3679 - val_accuracy: 0.8183
# Epoch 5/20
# 94/94 [==============================] - 15s 163ms/step - loss: 0.3838 - accuracy: 0.8647 - val_loss: 0.2670 - val_accuracy: 0.8850
# Epoch 6/20
# 94/94 [==============================] - 17s 183ms/step - loss: 0.2907 - accuracy: 0.8850 - val_loss: 0.2559 - val_accuracy: 0.8833
# Epoch 7/20
# 94/94 [==============================] - 14s 151ms/step - loss: 0.3390 - accuracy: 0.8623 - val_loss: 0.2623 - val_accuracy: 0.8733
# Epoch 8/20
# 94/94 [==============================] - 14s 151ms/step - loss: 0.3207 - accuracy: 0.8737 - val_loss: 0.5573 - val_accuracy: 0.8550
# Epoch 9/20
# 94/94 [==============================] - 18s 187ms/step - loss: 0.2822 - accuracy: 0.8837 - val_loss: 0.2519 - val_accuracy: 0.8817
# Epoch 10/20
# 94/94 [==============================] - 17s 186ms/step - loss: 0.3605 - accuracy: 0.8663 - val_loss: 0.3915 - val_accuracy: 0.8133
# Epoch 11/20
# 94/94 [==============================] - 14s 153ms/step - loss: 0.2325 - accuracy: 0.8967 - val_loss: 0.2451 - val_accuracy: 0.8883
# Epoch 12/20
# 94/94 [==============================] - 17s 177ms/step - loss: 0.2620 - accuracy: 0.8870 - val_loss: 0.2494 - val_accuracy: 0.8883
# Epoch 13/20
# 94/94 [==============================] - 18s 189ms/step - loss: 0.3392 - accuracy: 0.8753 - val_loss: 0.4620 - val_accuracy: 0.8667
# Epoch 14/20
# 94/94 [==============================] - 18s 189ms/step - loss: 0.3212 - accuracy: 0.8743 - val_loss: 0.6000 - val_accuracy: 0.8533
# Epoch 15/20
# 94/94 [==============================] - 14s 150ms/step - loss: 0.2301 - accuracy: 0.8943 - val_loss: 0.3023 - val_accuracy: 0.8533
# Epoch 16/20
# 94/94 [==============================] - 17s 181ms/step - loss: 0.2818 - accuracy: 0.8827 - val_loss: 0.3137 - val_accuracy: 0.8917
# Epoch 17/20
# 94/94 [==============================] - 16s 170ms/step - loss: 0.2397 - accuracy: 0.8937 - val_loss: 0.3900 - val_accuracy: 0.8050
# Epoch 18/20
# 94/94 [==============================] - 17s 180ms/step - loss: 0.2621 - accuracy: 0.8877 - val_loss: 0.2969 - val_accuracy: 0.8900
# Epoch 19/20
# 94/94 [==============================] - 17s 186ms/step - loss: 0.2204 - accuracy: 0.9047 - val_loss: 0.2387 - val_accuracy: 0.8867
# Epoch 20/20
# 94/94 [==============================] - 16s 167ms/step - loss: 0.1848 - accuracy: 0.9183 - val_loss: 0.2378 - val_accuracy: 0.8967

# %% [markdown]
# ## Testing Phase of Model-1

# %%
test_data=[]
img_height,img_width=224,224
for cls in classes:
  print(cls)
  for i in range(test_images_per_class):
    img_path=test_data_dir+'/'+cls+'/'+str(i)+'.png'
    img=image.load_img(img_path,target_size=(img_height,img_width))
    img_data=image.img_to_array(img)
    test_data.append(img_data)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
test_data_1=test_data

# %%
test_label_1=[]
test_label_1[:2*test_images_per_class]=[0]*2*test_images_per_class
test_label_1[2*test_images_per_class:]=[1]*4*test_images_per_class

# %%
test_data_1=np.asarray(test_data_1)
test_label_1=np.asarray(test_label_1)

# %%
for i in range(len(test_label_1)):
  test_data_1[i]=apply_filter_1(test_data_1[i])

# %%
test_data_1,test_label_1=preprocess_data(test_data_1,test_label_1,2)

# %%
test_data_1.shape,test_label_1.shape
# Out:
# ((1200, 224, 224, 3), (1200, 2))

# %%
test_loss,test_acc=resnet_model_1.evaluate(test_data_1,test_label_1,verbose=1)
# Out:
# 38/38 [==============================] - 9s 241ms/step - loss: 0.2178 - accuracy: 0.9058

# %%
print('Testing data accuracy = '+str(test_acc)+'\n Testing data loss = '+str(test_loss))
# Out:
# Testing data accuracy = 0.9058333039283752
#  Testing data loss = 0.21781226992607117

# %% [markdown]
# ## Saving the Model to the disk

# %%
model_json = resnet_model_1.to_json()
with open("/content/drive/MyDrive/summer intern/Models/filter_model_1.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
resnet_model_1.save_weights("/content/drive/MyDrive/summer intern/Models/filter_model_1.h5")
print("Saved model to disk")
 
# later...
# Out:
# Saved model to disk
