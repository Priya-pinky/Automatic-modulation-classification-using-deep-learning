# %% [markdown]
# ### This Model classifies the images into two classes:(8QAM and 16QAM) and (32QAM and 64QAM)

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import os
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers.core import Dense
from keras.layers.core import Flatten
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
from keras.preprocessing import image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir='/content/drive/MyDrive/summer intern/dataset/train'

# %%
test_data_dir='/content/drive/MyDrive/summer intern/dataset/test'

# %%
classes=[str(i) for i in range(6)]

# %%
val_data_dir='/content/drive/MyDrive/summer intern/dataset/valid'

# %%
train_images_per_class=500

# %%
def gen_circle(img: np.ndarray, center: tuple, diameter: int,fill_val: int) -> np.ndarray:
  
    """
        Creates a matrix of ones filling a circle.
    """

    # gets the radius of the image
    radius  = diameter//2

    # gets the row and column center of the image
    row, col = center 

    # generates theta vector to variate the angle
    theta = np.arange(0, 360)*(np.pi/180)

    # generates the indexes of the column
    y = (radius*np.sin(theta)).astype("int32") 

    # generates the indexes of the rows
    x = (radius*np.cos(theta)).astype("int32") 

    # with:
    # img[x, y] = 1
    # you can draw the border of the circle 
    # instead of the inner part and the border. 

    # centers the circle at the input center
    rows = x + (row)
    cols  = y + (col)

    # gets the number of rows and columns to make 
    # to cut by half the execution
    nrows = rows.shape[0] 
    ncols = cols.shape[0]

    # makes a copy of the image
    img_copy = np.copy(img)

    # We use the simetry in our favour
    # does reflection on the horizontal axes 
    # and in the vertical axes

    for row_down, row_up, col1, col2 in zip(rows[:nrows//4],
                            np.flip(rows[nrows//4:nrows//2]),
                            cols[:ncols//4],
                            cols[nrows//2:3*ncols//4]):
    
        img_copy[row_up:row_down, col2:col1] = fill_val

 
    return img_copy

# %%
from matplotlib import pyplot as plt
from PIL import Image
 
# Opens a image in RGB mode
newsize=(224,224)

sample_imgs=[19,8]
imgs=[]
for i in range(2,4):
  imgs.append(Image.open("/content/drive/MyDrive/summer intern/dataset/train/"+str(i)+'/'+str(sample_imgs[i-2])+".png").resize(newsize))
# create figure
fig = plt.figure(figsize=(15, 15))
  
# setting values to rows and column variables
rows = 1
columns = 2


for i in range(2):
  # Adds a subplot at the ith position
  fig.add_subplot(rows, columns, i+1)
  plt.imshow(imgs[i])

  
# showing image

# %%
# R filter
#Square

r_filter_dim=(24,200)
fil=np.zeros((224,224),dtype=int)
for i in range(r_filter_dim[0],r_filter_dim[1]):
  for j in range(r_filter_dim[0],r_filter_dim[1]):
    fil[i][j]=1
plt.imshow(fil)

# %%
# G filter

# two rectangles
g_filter_dim=[[24,55],[224-55,200],[24,200]]
fil=np.zeros((224,224),dtype=int)
#1st rectangle
for i in range(g_filter_dim[0][0],g_filter_dim[0][1]):
  for j in range(g_filter_dim[2][0],g_filter_dim[2][1]):
    fil[i][j]=1
#2nd rectangle 
for i in range(g_filter_dim[1][0],g_filter_dim[1][1]):
  for j in range(g_filter_dim[2][0],g_filter_dim[2][1]):
    fil[i][j]=1
plt.imshow(fil)

# %%
# B filter

# two rectangles
b_filter_dim=[[70,100],[224-100,224-70],[24,200]]
fil=np.zeros((224,224),dtype=int)
#1st rectangle
for i in range(b_filter_dim[0][0],b_filter_dim[0][1]):
  for j in range(b_filter_dim[2][0],b_filter_dim[2][1]):
    fil[i][j]=1
#2nd rectangle 
for i in range(b_filter_dim[1][0],b_filter_dim[1][1]):
  for j in range(b_filter_dim[2][0],b_filter_dim[2][1]):
    fil[i][j]=1
plt.imshow(fil)

# %%
def apply_filter(im):
  center = (112,112)

  #red layer filter 
  r_filter_dim=(24,200)
  fil=np.zeros((224,224),dtype=int)
  for i in range(r_filter_dim[0],r_filter_dim[1]):
    for j in range(r_filter_dim[0],r_filter_dim[1]):
      fil[i][j]=1
  im[:,:,0]=im[:,:,0]*fil


  #green layer filter
  g_filter_dim=[[24,55],[224-55,200],[24,200]]
  fil=np.zeros((224,224),dtype=int)
  #1st rectangle
  for i in range(g_filter_dim[0][0],g_filter_dim[0][1]):
    for j in range(g_filter_dim[2][0],g_filter_dim[2][1]):
      fil[i][j]=1
  #2nd rectangle 
  for i in range(g_filter_dim[1][0],g_filter_dim[1][1]):
    for j in range(g_filter_dim[2][0],g_filter_dim[2][1]):
      fil[i][j]=1
  im[:,:,1]=im[:,:,1]*fil


  #blue layer filter
  b_filter_dim=[[70,100],[224-100,224-70],[24,200]]
  fil=np.zeros((224,224),dtype=int)
  #1st rectangle
  for i in range(b_filter_dim[0][0],b_filter_dim[0][1]):
    for j in range(b_filter_dim[2][0],b_filter_dim[2][1]):
      fil[i][j]=1
  #2nd rectangle 
  for i in range(b_filter_dim[1][0],b_filter_dim[1][1]):
    for j in range(b_filter_dim[2][0],b_filter_dim[2][1]):
      fil[i][j]=1
  im[:,:,2]=im[:,:,2]*fil
  
  return im

# %%
def disp_filter_image(im):
  im=apply_filter(im)
  plt.imshow(im)
  plt.axis('off')

# %%
fil_imgs=[]
for i in range(2):
  fil_imgs.append(Image.open("/content/drive/MyDrive/summer intern/dataset/train/"+str(i+2)+'/'+str(sample_imgs[i])+".png").resize(newsize))
# create figure
fig = plt.figure(figsize=(15, 15))
  
# setting values to rows and column variables
rows = 1
columns = 2

for i in range(2):
  # Adds a subplot at the ith position
  fil_imgs[i]=apply_filter(np.array(fil_imgs[i]))
  fig.add_subplot(rows, columns, i+1)
  plt.imshow(fil_imgs[i])

# %%
train_data=[]
train_label=[]
img_height,img_width=224,224
for cls in classes[2:4]:
  print(cls)
  for i in range(500):
    img_path=data_dir+'/'+cls+'/'+str(i)+'.png'
    img=image.load_img(img_path,target_size=(img_height,img_width))
    img_data=image.img_to_array(img)
    train_data.append(img_data)
    train_label.append(int(cls))
# Out:
# 2
# 3

# %%
train_label[:train_images_per_class]=[0]*train_images_per_class
train_label[train_images_per_class:]=[1]*train_images_per_class

# %%
valid_images_per_class=100

# %%
valid_data=[]
valid_label=[]
img_height,img_width=224,224
for cls in classes[2:4]:
  print(cls)
  for i in range(100):
    img_path=val_data_dir+'/'+cls+'/'+str(i)+'.png'
    img=image.load_img(img_path,target_size=(img_height,img_width))
    img_data=image.img_to_array(img)
    valid_data.append(img_data)
    valid_label.append(int(cls))
# Out:
# 2
# 3

# %%
valid_label=[]
valid_label[:valid_images_per_class]=[0]*valid_images_per_class
valid_label[valid_images_per_class:]=[1]*valid_images_per_class

# %%
train_data=np.asarray(train_data)
train_label=np.asarray(train_label)

# %%
valid_data=np.asarray(valid_data)
valid_label=np.asarray(valid_label)

# %%
for i in range(len(train_label)):
  train_data[i]=apply_filter(train_data[i])

# %%
for i in range(len(valid_label)):
  valid_data[i]=apply_filter(valid_data[i])

# %%
def preprocess_data(X,Y,n):
  X_p=preprocess_input(X)
  Y_p=tf.keras.utils.to_categorical(Y,n)
  return (X_p,Y_p)

# %%
train_data,train_label=preprocess_data(train_data,train_label,2)

# %%
valid_data,valid_label=preprocess_data(valid_data,valid_label,2)

# %%
print(train_data.shape,train_label.shape)
# Out:
# (1000, 224, 224, 3) (1000, 2)

# %%
resnet_model = Sequential()
input_t=tf.keras.Input(shape=(224,224,3))
pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_tensor=input_t,
                   pooling='max',classes=2,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# 94781440/94765736 [==============================] - 2s 0us/step

# %%
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(2, activation='softmax'))

# %%
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 24,637,826
# Trainable params: 1,050,114
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
resnet_model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

history = resnet_model.fit(train_data,train_label, validation_data=(valid_data,valid_label),batch_size=32, epochs=25,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/25
# 32/32 [==============================] - 21s 207ms/step - loss: 4.4943 - accuracy: 0.6450 - val_loss: 1.3050 - val_accuracy: 0.7250
# Epoch 2/25
# 32/32 [==============================] - 4s 128ms/step - loss: 0.6890 - accuracy: 0.7660 - val_loss: 1.0428 - val_accuracy: 0.7000
# Epoch 3/25
# 32/32 [==============================] - 5s 163ms/step - loss: 0.9408 - accuracy: 0.7520 - val_loss: 0.5442 - val_accuracy: 0.7950
# Epoch 4/25
# 32/32 [==============================] - 4s 115ms/step - loss: 0.6182 - accuracy: 0.7820 - val_loss: 0.4115 - val_accuracy: 0.8200
# Epoch 5/25
# 32/32 [==============================] - 5s 159ms/step - loss: 0.3338 - accuracy: 0.8500 - val_loss: 0.3162 - val_accuracy: 0.8600
# Epoch 6/25
# 32/32 [==============================] - 4s 129ms/step - loss: 0.3370 - accuracy: 0.8500 - val_loss: 0.3349 - val_accuracy: 0.8550
# Epoch 7/25
# 32/32 [==============================] - 5s 145ms/step - loss: 0.3094 - accuracy: 0.8410 - val_loss: 0.9825 - val_accuracy: 0.7150
# Epoch 8/25
# 32/32 [==============================] - 4s 132ms/step - loss: 0.2958 - accuracy: 0.8630 - val_loss: 0.2837 - val_accuracy: 0.8650
# Epoch 9/25
# 32/32 [==============================] - 5s 157ms/step - loss: 0.2950 - accuracy: 0.8620 - val_loss: 0.7115 - val_accuracy: 0.7450
# Epoch 10/25
# 32/32 [==============================] - 6s 179ms/step - loss: 0.3991 - accuracy: 0.8180 - val_loss: 0.4125 - val_accuracy: 0.8200
# Epoch 11/25
# 32/32 [==============================] - 5s 153ms/step - loss: 0.7480 - accuracy: 0.7710 - val_loss: 0.3814 - val_accuracy: 0.8300
# Epoch 12/25
# 32/32 [==============================] - 5s 153ms/step - loss: 0.2348 - accuracy: 0.8920 - val_loss: 0.2891 - val_accuracy: 0.8800
# Epoch 13/25
# 32/32 [==============================] - 5s 170ms/step - loss: 0.2180 - accuracy: 0.9070 - val_loss: 0.3388 - val_accuracy: 0.8400
# Epoch 14/25
# 32/32 [==============================] - 5s 158ms/step - loss: 0.2488 - accuracy: 0.8820 - val_loss: 0.3726 - val_accuracy: 0.8250
# Epoch 15/25
# 32/32 [==============================] - 4s 141ms/step - loss: 0.1838 - accuracy: 0.9200 - val_loss: 0.2797 - val_accuracy: 0.8700
# Epoch 16/25
# 32/32 [==============================] - 5s 146ms/step - loss: 0.2094 - accuracy: 0.9040 - val_loss: 0.2802 - val_accuracy: 0.8600
# Epoch 17/25
# 32/32 [==============================] - 5s 157ms/step - loss: 0.2051 - accuracy: 0.9190 - val_loss: 0.2964 - val_accuracy: 0.8850
# Epoch 18/25
# 32/32 [==============================] - 4s 129ms/step - loss: 0.1831 - accuracy: 0.9170 - val_loss: 0.5108 - val_accuracy: 0.7900
# Epoch 19/25
# 32/32 [==============================] - 5s 156ms/step - loss: 0.2749 - accuracy: 0.8680 - val_loss: 0.5141 - val_accuracy: 0.7800
# Epoch 20/25
# 32/32 [==============================] - 6s 194ms/step - loss: 0.2428 - accuracy: 0.9020 - val_loss: 0.3999 - val_accuracy: 0.8350
# Epoch 21/25
# 32/32 [==============================] - 6s 205ms/step - loss: 0.1248 - accuracy: 0.9610 - val_loss: 0.2807 - val_accuracy: 0.8650
# Epoch 22/25
# 32/32 [==============================] - 5s 157ms/step - loss: 0.1067 - accuracy: 0.9730 - val_loss: 0.2766 - val_accuracy: 0.8700
# Epoch 23/25
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1039 - accuracy: 0.9710 - val_loss: 0.3087 - val_accuracy: 0.8600
# Epoch 24/25
# 32/32 [==============================] - 5s 143ms/step - loss: 0.1103 - accuracy: 0.9630 - val_loss: 0.3069 - val_accuracy: 0.8650
# Epoch 25/25
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1057 - accuracy: 0.9640 - val_loss: 0.5759 - val_accuracy: 0.7650

# %%
test_images_per_class=100

# %%
test_data=[]
test_label=[]
img_height,img_width=224,224
for cls in classes[2:4]:
  print(cls)
  for i in range(100):
    img_path=test_data_dir+'/'+cls+'/'+str(i)+'.png'
    img=image.load_img(img_path,target_size=(img_height,img_width))
    img_data=image.img_to_array(img)
    test_data.append(img_data)
    test_label.append(int(cls))
# Out:
# 2
# 3

# %%
test_label=[]
test_label[:test_images_per_class]=[0]*test_images_per_class
test_label[test_images_per_class:]=[1]*test_images_per_class

# %%
test_data=np.asarray(test_data)
test_label=np.asarray(test_label)

# %%
for i in range(len(test_label)):
  test_data[i]=apply_filter(test_data[i])

# %%
test_data,test_label=preprocess_data(test_data,test_label,2)

# %%
test_data.shape,test_label.shape
# Out:
# ((200, 224, 224, 3), (200, 2))

# %%
predictions=resnet_model.predict(test_data,verbose=1)
# Out:
# 7/7 [==============================] - 4s 519ms/step

# %%
test_loss,test_acc=resnet_model.evaluate(test_data,test_label,verbose=1)
# Out:
# 7/7 [==============================] - 1s 84ms/step - loss: 0.5990 - accuracy: 0.7800

# %%
print('Testing data accuracy = '+str(test_acc)+'\n Testing data loss = '+str(test_loss))
# Out:
# Testing data accuracy = 0.7799999713897705
#  Testing data loss = 0.59897780418396

# %%
predictions
# Out:
# array([[9.88471508e-01, 1.15284473e-02],
#        [9.99661565e-01, 3.38423066e-04],
#        [2.80968193e-02, 9.71903145e-01],
#        [3.26518327e-01, 6.73481643e-01],
#        [1.28758270e-02, 9.87124205e-01],
#        [2.54084449e-02, 9.74591613e-01],
#        [9.39715266e-01, 6.02847710e-02],
#        [9.99488115e-01, 5.11909428e-04],
#        [7.83633590e-02, 9.21636701e-01],
#        [9.96392906e-01, 3.60711291e-03],
#        [2.88301229e-01, 7.11698771e-01],
#        [9.82342780e-01, 1.76571775e-02],
#        [9.99719322e-01, 2.80667125e-04],
#        [9.99993324e-01, 6.66830965e-06],
#        [9.99988198e-01, 1.18219705e-05],
#        [9.78510857e-01, 2.14891620e-02],
#        [9.99899745e-01, 1.00229983e-04],
#        [4.61276807e-02, 9.53872323e-01],
#        [9.98433769e-01, 1.56615942e-03],
#        [5.36348343e-01, 4.63651627e-01],
#        [8.30455005e-01, 1.69545010e-01],
#        [3.27320993e-02, 9.67267931e-01],
#        [9.56613600e-01, 4.33864184e-02],
#        [3.71726662e-01, 6.28273368e-01],
#        [7.78613687e-01, 2.21386328e-01],
#        [4.11936969e-01, 5.88063002e-01],
#        [1.60601020e-01, 8.39399040e-01],
#        [9.99485493e-01, 5.14427957e-04],
#        [9.99951482e-01, 4.85177334e-05],
#        [2.00429410e-01, 7.99570560e-01],
#        [9.99755323e-01, 2.44678900e-04],
#        [8.41890797e-02, 9.15810883e-01],
#        [7.81232910e-03, 9.92187619e-01],
#        [9.27593231e-01, 7.24066943e-02],
#        [9.99986291e-01, 1.36502586e-05],
#        [9.99864101e-01, 1.35937793e-04],
#        [1.62223071e-01, 8.37776899e-01],
#        [3.69945378e-03, 9.96300578e-01],
#        [3.15089524e-02, 9.68491018e-01],
#        [4.17588204e-02, 9.58241165e-01],
#        [9.99999881e-01, 9.38623330e-08],
#        [9.85095918e-01, 1.49041107e-02],
#        [1.66307800e-02, 9.83369291e-01],
#        [4.19652946e-02, 9.58034635e-01],
#        [9.99999404e-01, 5.69306053e-07],
#        [9.94567156e-01, 5.43283485e-03],
#        [2.66219899e-02, 9.73378062e-01],
#        [9.96759355e-01, 3.24066519e-03],
#        [9.25297379e-01, 7.47026429e-02],
#        [9.99997616e-01, 2.37340760e-06],
#        [9.99378562e-01, 6.21421263e-04],
#        [9.99999762e-01, 1.87633816e-07],
#        [9.99627829e-01, 3.72168171e-04],
#        [1.86281204e-01, 8.13718855e-01],
#        [3.33708435e-01, 6.66291535e-01],
#        [9.99711215e-01, 2.88816751e-04],
#        [1.08960763e-01, 8.91039252e-01],
#        [9.99981761e-01, 1.82127551e-05],
#        [9.91426945e-01, 8.57310742e-03],
#        [1.00000000e+00, 4.71505404e-11],
#        [5.54019623e-02, 9.44598079e-01],
#        [1.00000000e+00, 1.47924046e-08],
#        [5.66776931e-01, 4.33223099e-01],
#        [4.43787873e-02, 9.55621183e-01],
#        [9.58615780e-01, 4.13841642e-02],
#        [3.51918817e-01, 6.48081183e-01],
#        [1.69930503e-01, 8.30069542e-01],
#        [4.07457590e-01, 5.92542350e-01],
#        [9.99999881e-01, 1.13492220e-07],
#        [9.99948621e-01, 5.14164203e-05],
#        [1.00000000e+00, 1.60867710e-08],
#        [2.72515982e-01, 7.27483988e-01],
#        [9.97962832e-01, 2.03721225e-03],
#        [9.99999166e-01, 8.58673275e-07],
#        [1.08098285e-02, 9.89190221e-01],
#        [9.95920539e-01, 4.07948997e-03],
#        [1.88312605e-01, 8.11687350e-01],
#        [9.99996305e-01, 3.73075704e-06],
#        [5.36207139e-01, 4.63792890e-01],
#        [1.46618234e-02, 9.85338211e-01],
#        [7.47351497e-02, 9.25264776e-01],
#        [4.98025976e-02, 9.50197399e-01],
#        [9.84821022e-01, 1.51790176e-02],
#        [9.99999762e-01, 2.58627892e-07],
#        [5.67915738e-01, 4.32084292e-01],
#        [9.99332845e-01, 6.67130051e-04],
#        [8.91657233e-01, 1.08342759e-01],
#        [5.23806550e-02, 9.47619379e-01],
#        [2.95272171e-01, 7.04727829e-01],
#        [3.47319394e-01, 6.52680635e-01],
#        [9.14091468e-02, 9.08590853e-01],
#        [5.76223247e-02, 9.42377687e-01],
#        [8.45667601e-01, 1.54332370e-01],
#        [9.99999166e-01, 7.84413487e-07],
#        [3.94696981e-01, 6.05303049e-01],
#        [9.99193490e-01, 8.06463184e-04],
#        [1.00000000e+00, 3.87960419e-09],
#        [9.98242378e-01, 1.75761699e-03],
#        [9.99981523e-01, 1.84338005e-05],
#        [1.09116947e-02, 9.89088297e-01],
#        [3.01227421e-01, 6.98772550e-01],
#        [5.94478697e-02, 9.40552175e-01],
#        [1.56781718e-03, 9.98432219e-01],
#        [8.31381604e-03, 9.91686165e-01],
#        [1.07250633e-02, 9.89274919e-01],
#        [3.47622149e-02, 9.65237737e-01],
#        [6.69339672e-02, 9.33066010e-01],
#        [8.41109257e-04, 9.99158859e-01],
#        [6.27639820e-05, 9.99937177e-01],
#        [1.81603446e-05, 9.99981880e-01],
#        [2.02986598e-02, 9.79701281e-01],
#        [4.52463019e-06, 9.99995470e-01],
#        [3.62900465e-07, 9.99999642e-01],
#        [6.87751174e-03, 9.93122518e-01],
#        [3.23379226e-03, 9.96766210e-01],
#        [5.85570092e-07, 9.99999404e-01],
#        [2.10241929e-01, 7.89758086e-01],
#        [2.35519587e-06, 9.99997616e-01],
#        [3.73365424e-07, 9.99999642e-01],
#        [3.50294821e-02, 9.64970469e-01],
#        [2.15905765e-03, 9.97840881e-01],
#        [1.33006768e-02, 9.86699343e-01],
#        [6.46672424e-06, 9.99993563e-01],
#        [2.74004037e-06, 9.99997258e-01],
#        [1.45094446e-03, 9.98549044e-01],
#        [2.12613289e-04, 9.99787390e-01],
#        [1.27173567e-04, 9.99872804e-01],
#        [1.60089154e-02, 9.83991146e-01],
#        [1.90714654e-03, 9.98092830e-01],
#        [1.11046411e-05, 9.99988914e-01],
#        [4.47665453e-01, 5.52334607e-01],
#        [1.24507412e-01, 8.75492632e-01],
#        [5.81682622e-02, 9.41831708e-01],
#        [1.68125525e-01, 8.31874490e-01],
#        [1.47871912e-01, 8.52128088e-01],
#        [4.17726971e-02, 9.58227277e-01],
#        [1.00405043e-04, 9.99899626e-01],
#        [8.44742581e-02, 9.15525734e-01],
#        [1.76590547e-05, 9.99982357e-01],
#        [3.46594700e-03, 9.96533990e-01],
#        [4.32566255e-02, 9.56743360e-01],
#        [5.18749505e-02, 9.48125005e-01],
#        [2.70430337e-06, 9.99997258e-01],
#        [1.72388136e-01, 8.27611923e-01],
#        [1.91607370e-07, 9.99999762e-01],
#        [1.48149440e-02, 9.85185027e-01],
#        [7.62981968e-03, 9.92370129e-01],
#        [2.36699194e-07, 9.99999762e-01],
#        [8.22271034e-03, 9.91777301e-01],
#        [4.16205182e-07, 9.99999642e-01],
#        [3.35355935e-06, 9.99996662e-01],
#        [4.83392398e-07, 9.99999523e-01],
#        [9.68030542e-02, 9.03196990e-01],
#        [6.12412207e-03, 9.93875921e-01],
#        [3.14846635e-02, 9.68515396e-01],
#        [1.33394018e-01, 8.66605997e-01],
#        [3.20319436e-03, 9.96796787e-01],
#        [8.30824149e-07, 9.99999166e-01],
#        [4.68358025e-02, 9.53164160e-01],
#        [1.08407050e-01, 8.91592920e-01],
#        [8.16262793e-03, 9.91837323e-01],
#        [4.17376896e-07, 9.99999523e-01],
#        [1.26698535e-06, 9.99998689e-01],
#        [2.46106144e-02, 9.75389361e-01],
#        [7.98352957e-01, 2.01647043e-01],
#        [7.53101006e-07, 9.99999285e-01],
#        [4.77343891e-03, 9.95226502e-01],
#        [1.56146655e-07, 9.99999881e-01],
#        [2.04214882e-02, 9.79578555e-01],
#        [7.08848331e-03, 9.92911518e-01],
#        [6.64032006e-04, 9.99335945e-01],
#        [1.93050742e-01, 8.06949258e-01],
#        [3.65236104e-07, 9.99999642e-01],
#        [4.92520444e-03, 9.95074809e-01],
#        [2.05812663e-01, 7.94187367e-01],
#        [5.16516948e-03, 9.94834781e-01],
#        [9.77647398e-03, 9.90223467e-01],
#        [2.04059930e-07, 9.99999762e-01],
#        [1.07838489e-01, 8.92161548e-01],
#        [3.10120732e-03, 9.96898770e-01],
#        [4.01355101e-05, 9.99959826e-01],
#        [7.05799584e-06, 9.99992967e-01],
#        [9.31025541e-04, 9.99069035e-01],
#        [7.91636109e-02, 9.20836449e-01],
#        [2.78534442e-01, 7.21465528e-01],
#        [6.54984415e-01, 3.45015645e-01],
#        [1.40838223e-04, 9.99859095e-01],
#        [1.27460780e-02, 9.87253964e-01],
#        [3.65690971e-06, 9.99996305e-01],
#        [3.00320778e-02, 9.69967961e-01],
#        [9.33801697e-04, 9.99066174e-01],
#        [3.79144147e-08, 1.00000000e+00],
#        [5.01387547e-07, 9.99999523e-01],
#        [1.40945031e-03, 9.98590529e-01],
#        [3.41856503e-05, 9.99965787e-01],
#        [2.45671421e-01, 7.54328549e-01],
#        [1.48049605e-06, 9.99998569e-01],
#        [3.30578089e-01, 6.69421911e-01],
#        [3.11368167e-01, 6.88631833e-01],
#        [5.26510064e-07, 9.99999523e-01]], dtype=float32)

# %%
from tensorflow.keras.models import model_from_json

# %%
model_json = resnet_model.to_json()
with open("/content/drive/MyDrive/summer intern/filter_model_3.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
resnet_model.save_weights("/content/drive/MyDrive/summer intern/filter_model_3.h5")
print("Saved model to disk")
 
# later...
# Out:
# Saved model to disk
