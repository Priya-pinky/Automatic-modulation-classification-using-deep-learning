# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import os
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers.core import Dense
from keras.layers.core import Flatten
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
from keras.preprocessing import image as imag
from PIL import Image

# %%
data_dir='/content/drive/MyDrive/Summer Intern Project/dataset/train'

# %%
test_data_dir='/content/drive/MyDrive/Summer Intern Project/dataset/test'

# %%
img_height,img_width=224,224
img_path=data_dir+'/0/1.png'
img=imag.load_img(img_path,target_size=(img_height,img_width))
img_data=imag.img_to_array(img)
img_data=np.expand_dims(img_data,axis=0)
img_data=preprocess_input(img_data)

# %%
from matplotlib import pyplot as plt
from PIL import Image
 
# Opens a image in RGB mode
newsize=(224,224)
im1 = Image.open(r"/content/drive/MyDrive/Summer Intern Project/dataset/train/0/800.png")
im1 = im1.resize(newsize)
im2 = Image.open(r"/content/drive/MyDrive/Summer Intern Project/dataset/train/1/800.png")
im2 = im2.resize(newsize)
print(type(im1))
# create figure
fig = plt.figure(figsize=(15, 15))
  
# setting values to rows and column variables
rows = 1
columns = 2

  
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(im1)
plt.title("First")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(im2)
plt.title("Second")
# Out:
# <class 'PIL.Image.Image'>
# Text(0.5, 1.0, 'Second')

# %%
r_filter_dim=(24,200)

# %%
# for qpsk
dis=37
g_filter_dim=[(dis,112),(112,dis),(224-dis,112),(112,224-dis)]

# %%
# for 8 psk
x=60
b_filter_dim=[(x,x),(x,224-x),(224-x,x),(224-x,224-x),(dis,112),(112,dis),(224-dis,112),(112,224-dis)]

# %%
def gen_circle(img: np.ndarray, center: tuple, diameter: int) -> np.ndarray:
  
    """
        Creates a matrix of ones filling a circle.
    """

    # gets the radius of the image
    radius  = diameter//2

    # gets the row and column center of the image
    row, col = center 

    # generates theta vector to variate the angle
    theta = np.arange(0, 360)*(np.pi/180)

    # generates the indexes of the column
    y = (radius*np.sin(theta)).astype("int32") 

    # generates the indexes of the rows
    x = (radius*np.cos(theta)).astype("int32") 

    # with:
    # img[x, y] = 1
    # you can draw the border of the circle 
    # instead of the inner part and the border. 

    # centers the circle at the input center
    rows = x + (row)
    cols  = y + (col)

    # gets the number of rows and columns to make 
    # to cut by half the execution
    nrows = rows.shape[0] 
    ncols = cols.shape[0]

    # makes a copy of the image
    img_copy = np.copy(img)

    # We use the simetry in our favour
    # does reflection on the horizontal axes 
    # and in the vertical axes

    for row_down, row_up, col1, col2 in zip(rows[:nrows//4],
                            np.flip(rows[nrows//4:nrows//2]),
                            cols[:ncols//4],
                            cols[nrows//2:3*ncols//4]):
    
        img_copy[row_up:row_down, col2:col1] = 1

 
    return img_copy

# %%
def apply_filter(im):
  center = (112,112)
  #red layer filter 
  rect=np.zeros((224,224))
  for i in range(r_filter_dim[0],r_filter_dim[1]+1):
    for j in range(r_filter_dim[0],r_filter_dim[1]+1):
      rect[i][j]=1
  im[:,:,0]=im[:,:,0]*rect

  #blue layer filter
  circle = np.zeros((center[0]*2, center[1]*2))
  diameter = 25
  for i in range(4):
    circle = gen_circle(circle,g_filter_dim[i], diameter)
  im[:,:,1]=im[:,:,1]*circle


  #blue layer filter
  circle_1 = np.zeros((center[0]*2, center[1]*2))
  diameter = 25
  for i in range(4):
    circle_1 = gen_circle(circle_1,b_filter_dim[i], diameter)
  im[:,:,2]=im[:,:,2]*circle_1
  return im

# %%
center = (112,112)
#red layer filter 
rect=np.zeros((224,224))
for i in range(r_filter_dim[0],r_filter_dim[1]+1):
  for j in range(r_filter_dim[0],r_filter_dim[1]+1):
    rect[i][j]=1
plt.imshow(rect)

# %%
#blue layer filter
circle = np.zeros((center[0]*2, center[1]*2))
diameter = 25
for i in range(4):
  circle = gen_circle(circle,g_filter_dim[i], diameter)
plt.imshow(circle)

# %%
circle_1 = np.zeros((center[0]*2, center[1]*2))
diameter = 25
for i in range(4):
  circle_1 = gen_circle(circle_1,b_filter_dim[i], diameter)
plt.imshow(circle_1)

# %%
def disp_filter_image(im):
  im=apply_filter(im)
  plt.imshow(im)
  plt.axis('off')

# %%
im1=np.array(im1)
disp_filter_image(im1)

# %%
im2=np.array(im2)
disp_filter_image(im2)

# %%
classes=[str(i) for i in range(6)]

# %%
val_data_dir='/content/drive/MyDrive/Summer Intern Project/dataset/valid'

# %%
def preprocess_data(X,Y,n):
  X_p=preprocess_input(X)
  Y_p=tf.keras.utils.to_categorical(Y,n)
  return (X_p,Y_p)

# %% [markdown]
# ## Model

# %%
train_data_1=[]
img_height,img_width=224,224
for cls in range(2):
  print(cls)
  for i in range(1050):
    img_path=data_dir+'/'+str(cls)+'/'+str(i)+'.png'
    img=imag.load_img(img_path,target_size=(img_height,img_width))
    img_data=imag.img_to_array(img)
    train_data_1.append(img_data)
# Out:
# 0
# 1

# %%
imgs_cnt=len(train_data_1)

# %%
train_images_per_class = 1050

# %%
train_label_1=[]
train_label_1[:train_images_per_class]=[0]*train_images_per_class
train_label_1[train_images_per_class:]=[1]*train_images_per_class

# %%
train_data_1=np.asarray(train_data_1)
train_label_1=np.asarray(train_label_1)

# %%
valid_data_1=[]
valid_label_1=[]
img_height,img_width=224,224
for cls in range(2):
  print(cls)
  for i in range(350):
    img_path=val_data_dir+'/'+str(cls)+'/'+str(i)+'.png'
    img=imag.load_img(img_path,target_size=(img_height,img_width))
    img_data=imag.img_to_array(img)
    valid_data_1.append(img_data)
# Out:
# 0
# 1

# %%
valid_images_per_class=350

# %%
valid_label_1[:valid_images_per_class]=[0]*valid_images_per_class
valid_label_1[valid_images_per_class:]=[1]*valid_images_per_class

# %%
valid_imgs_cnt=len(valid_data_1)

# %%
valid_data_1=np.asarray(valid_data_1)
valid_label_1=np.asarray(valid_label_1)

# %%
for i in range(imgs_cnt):
  train_data_1[i]=apply_filter(train_data_1[i])

# %%
for i in range(valid_imgs_cnt):
  valid_data_1[i]=apply_filter(valid_data_1[i])

# %%
train_data_1,train_label_1=preprocess_data(train_data_1,train_label_1,2)

# %%
valid_data_1,valid_label_1=preprocess_data(valid_data_1,valid_label_1,2)

# %%
valid_label_1.shape
# Out:
# (700, 2)

# %%
print(train_data_1.shape,train_label_1.shape)
# Out:
# (2100, 224, 224, 3) (2100, 2)

# %%
resnet_model_1 = Sequential()
input_t=tf.keras.Input(shape=(224,224,3))
pretrained_model_1= tf.keras.applications.ResNet50(include_top=False,
                   input_tensor=input_t,
                   pooling='max',classes=2,
                   weights='imagenet')
for layer in pretrained_model_1.layers:
        layer.trainable=False

resnet_model_1.add(pretrained_model_1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
resnet_model_1.add(Flatten())
resnet_model_1.add(Dense(512, activation='relu'))
resnet_model_1.add(Dense(2, activation='softmax'))

# %%
resnet_model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 24,637,826
# Trainable params: 1,050,114
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
resnet_model_1.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

history_1 = resnet_model_1.fit(train_data_1,train_label_1,validation_data=(valid_data_1,valid_label_1),batch_size=32, epochs=25,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/25
# 66/66 [==============================] - 33s 286ms/step - loss: 3.5319 - accuracy: 0.7786 - val_loss: 0.3513 - val_accuracy: 0.8971
# Epoch 2/25
# 66/66 [==============================] - 14s 210ms/step - loss: 0.3041 - accuracy: 0.8852 - val_loss: 0.2678 - val_accuracy: 0.9014
# Epoch 3/25
# 66/66 [==============================] - 13s 206ms/step - loss: 0.2548 - accuracy: 0.8981 - val_loss: 0.2121 - val_accuracy: 0.9029
# Epoch 4/25
# 66/66 [==============================] - 15s 227ms/step - loss: 0.2320 - accuracy: 0.9033 - val_loss: 0.1964 - val_accuracy: 0.9114
# Epoch 5/25
# 66/66 [==============================] - 13s 202ms/step - loss: 0.2943 - accuracy: 0.8995 - val_loss: 0.2860 - val_accuracy: 0.8957
# Epoch 6/25
# 66/66 [==============================] - 12s 187ms/step - loss: 0.2032 - accuracy: 0.9181 - val_loss: 0.2715 - val_accuracy: 0.8900
# Epoch 7/25
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1512 - accuracy: 0.9338 - val_loss: 0.2762 - val_accuracy: 0.9014
# Epoch 8/25
# 66/66 [==============================] - 15s 235ms/step - loss: 0.1435 - accuracy: 0.9357 - val_loss: 0.1995 - val_accuracy: 0.9014
# Epoch 9/25
# 66/66 [==============================] - 12s 184ms/step - loss: 0.1801 - accuracy: 0.9248 - val_loss: 0.2035 - val_accuracy: 0.9114
# Epoch 10/25
# 66/66 [==============================] - 14s 215ms/step - loss: 0.1379 - accuracy: 0.9371 - val_loss: 0.2000 - val_accuracy: 0.9129
# Epoch 11/25
# 66/66 [==============================] - 12s 190ms/step - loss: 0.1178 - accuracy: 0.9424 - val_loss: 0.3006 - val_accuracy: 0.8886
# Epoch 12/25
# 11/66 [====>.........................] - ETA: 9s - loss: 0.1255 - accuracy: 0.9403
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-9204df7cb3f2> in <module>
#       1 resnet_model_1.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
#       2
# ----> 3 history_1 = resnet_model_1.fit(train_data_1,train_label_1,validation_data=(valid_data_1,valid_label_1),batch_size=32, epochs=25,verbose=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1105       # Only block async when verbose = 1.
#    1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#    1109   def _finalize_progbar(self, logs, counter):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     974
#     975       message += info
# --> 976       io_utils.print_msg(message, line_break=False)
#     977       message = ''
#     978
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/io_utils.py in print_msg(message, line_break)
#      36     else:
#      37       sys.stdout.write(message)
# ---> 38     sys.stdout.flush()
#      39
#      40
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in flush(self)
#     350                 self.pub_thread.schedule(evt.set)
#     351                 # and give a timeout to avoid
# --> 352                 if not evt.wait(self.flush_timeout):
#     353                     # write directly to __stderr__ instead of warning because
#     354                     # if this is happening sys.stderr may be the problem.
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
test_data_1=[]
img_height,img_width=224,224
for cls in range(2):
  print(cls)
  for i in range(100):
    img_path=test_data_dir+'/'+str(cls)+'/'+str(i)+'.png'
    img=imag.load_img(img_path,target_size=(img_height,img_width))
    img_data=imag.img_to_array(img)
    test_data_1.append(img_data)
# Out:
# 0
# 1

# %%
test_images_per_class=100

# %%
test_label_1=[]
test_label_1[:test_images_per_class]=[0]*test_images_per_class
test_label_1[test_images_per_class:]=[1]*test_images_per_class

# %%
test_data_1=np.asarray(test_data_1)
test_label_1=np.asarray(test_label_1)

# %%
for i in range(200):
  test_data_1[i]=apply_filter(test_data_1[i])

# %%
test_data_1,test_label_1=preprocess_data(test_data_1,test_label_1,2)

# %%
test_data_1.shape,test_label_1.shape
# Out:
# ((200, 224, 224, 3), (200, 2))

# %%
predictions_1=resnet_model_1.predict(test_data_1,verbose=1)
# Out:
# 7/7 [==============================] - 1s 190ms/step

# %%
test_loss_1,test_acc_1=resnet_model_1.evaluate(test_data_1,test_label_1,verbose=1)
# Out:
# 7/7 [==============================] - 4s 691ms/step - loss: 0.2789 - accuracy: 0.9150

# %%
print('Testing data accuracy = '+str(test_acc_1)+'\n Testing data loss = '+str(test_loss_1))
# Out:
# Testing data accuracy = 0.9150000214576721
#  Testing data loss = 0.2788929343223572

# %%
model_json_1 = resnet_model_1.to_json()
with open("/content/drive/MyDrive/Summer Intern Project/filter_model_1.json", "w") as json_file:
    json_file.write(model_json_1)
# serialize weights to HDF5
resnet_model_1.save_weights("/content/drive/MyDrive/Summer Intern Project/filter_model_1.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
